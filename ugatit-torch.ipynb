# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ugatit
# Out:
# /content/drive/MyDrive/ugatit

# %%
# !git clone https://github.com/rayhwang3130/KUBIG-UGATIT-torch
# Out:
# Cloning into 'UGATIT-torch'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 91 (delta 26), reused 89 (delta 26), pack-reused 1
# Unpacking objects: 100% (91/91), 5.43 MiB | 4.33 MiB/s, done.

# %%
import torch
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Thu Jul  6 05:34:34 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    46W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python /content/drive/MyDrive/ugatit/UGATIT-torch/main.py --dataset /content/drive/MyDrive/datasets_final --phase train --iteration 100000 --batch_size 2 --n_dis 4 --save_freq 1000
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [13785/100000] time: 10548.3891 d_loss: 2.59211493, g_loss: 38.48797607
# [13786/100000] time: 10549.0335 d_loss: 2.61922789, g_loss: 19.32720947
# [13787/100000] time: 10549.6670 d_loss: 2.36047196, g_loss: 26.88177872
# [13788/100000] time: 10550.3069 d_loss: 2.10871792, g_loss: 151.68904114
# [13789/100000] time: 10550.9524 d_loss: 2.13770938, g_loss: 18.71406364
# [13790/100000] time: 10551.5847 d_loss: 1.96968579, g_loss: 18.29678726
# [13791/100000] time: 10552.2397 d_loss: 3.36270475, g_loss: 24.26720047
# [13792/100000] time: 10552.8589 d_loss: 2.46571469, g_loss: 63.77690506
# [13793/100000] time: 10553.4977 d_loss: 2.32435656, g_loss: 26.45713043
# [13794/100000] time: 10554.1293 d_loss: 2.99815011, g_loss: 18.75356674
# [13795/100000] time: 10554.7667 d_loss: 2.80992794, g_loss: 17.46819305
# [13796/100000] time: 10555.4234 d_loss: 3.31617165, g_loss: 21.31788635
# ...

# %%
# !python /content/drive/MyDrive/ugatit/UGATIT-torch/main.py --dataset /content/drive/MyDrive/datasets_final --phase test --n_dis 4
# Out:
# ##### Information #####
# # light :  False
# # dataset :  /content/drive/MyDrive/datasets_final
# # batch_size :  1
# # iteration per epoch :  1000
#
# ##### Generator #####
# # residual blocks :  4
#
# ##### Discriminator #####
# # discriminator layer :  4
#
# ##### Weight #####
# # adv_weight :  1
# # cycle_weight :  10
# # identity_weight :  10
# # cam_weight :  1000
#  [*] Load SUCCESS
#  [*] Test finished!
